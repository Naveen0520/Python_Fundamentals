# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = [1,3,5]
y = [1,4,7]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.title('sales information')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y)
plt.show()

# %%
z = [10,5,0]

# %%
plt.title('sales information')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y)
plt.plot(x,z)
plt.show()

# %%
plt.title('sales information')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y)
plt.plot(x,z)
plt.legend(["this is x and y","this is x and z"])
plt.show()

# %%
sd = pd.read_csv('sample_data (2).csv')

sd
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sd)
# Out:
# pandas.core.frame.DataFrame

# %%
sd.column_b
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# Name: column_b, dtype: int64

# %%
sd.column_c
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
type(sd.column_c)
# Out:
# pandas.core.series.Series

# %%
plt.plot(sd.column_a,sd.column_b)
plt.show()

# %%
plt.plot(sd.column_a,sd.column_b)
plt.title('data processing')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
plt.plot(sd.column_a,sd.column_b)
plt.plot(sd.column_a,sd.column_c)
plt.title('data processing')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend(["this is a and b","this is a and c"])
plt.show()

# %%
data = pd.read_csv('countries (2).csv')

data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
us = data[data.country == 'United States']

us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
china = data[data.country == 'China']

china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year,us.population)
plt.show()

# %%
plt.plot(china.year,china.population)
plt.show()

# %%
plt.plot(china.year,china.population/10**6)
plt.plot(us.year,us.population/10**6)
plt.title('comparision of countries population')
plt.xlabel('years')
plt.ylabel('population')
plt.legend(["this is us","this is China"])
plt.show()

# %%
country1 = data[data.country == 'Afghanistan']

country1
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
country2 = data[data.country == 'Albania']

country2
# Out:
#     country  year  population
# 12  Albania  1952     1282697
# 13  Albania  1957     1476505
# 14  Albania  1962     1728137
# 15  Albania  1967     1984060
# 16  Albania  1972     2263554
# 17  Albania  1977     2509048
# 18  Albania  1982     2780097
# 19  Albania  1987     3075321
# 20  Albania  1992     3326498
# 21  Albania  1997     3428038
# 22  Albania  2002     3508512
# 23  Albania  2007     3600523

# %%
plt.plot(country1.year,country1.population/10**6)
plt.plot(country2.year,country2.population/10**6)
plt.title('comparision of countries population')
plt.xlabel('year')
plt.ylabel('population')
plt.legend(["this is country1","this is country2"])
plt.show()

# %%
country3 = data[data.country == 'India']

country3
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
country4 = data[data.country == 'Pakistan']

country4
# Out:
#        country  year  population
# 1164  Pakistan  1952    41346560
# 1165  Pakistan  1957    46679944
# 1166  Pakistan  1962    53100671
# 1167  Pakistan  1967    60641899
# 1168  Pakistan  1972    69325921
# 1169  Pakistan  1977    78152686
# 1170  Pakistan  1982    91462088
# 1171  Pakistan  1987   105186881
# 1172  Pakistan  1992   120065004
# 1173  Pakistan  1997   135564834
# 1174  Pakistan  2002   153403524
# 1175  Pakistan  2007   169270617

# %%
plt.plot(country3.year,country3.population/10**6)
plt.plot(country4.year,country4.population/10**6)
plt.title('comparision of two countries')
plt.xlabel('year')
plt.ylabel('population')
plt.legend(["this is country3","this is country4"])
plt.show()

# %%
country5 = data[data.country == 'Australia']

country5
# Out:
#       country  year  population
# 60  Australia  1952     8691212
# 61  Australia  1957     9712569
# 62  Australia  1962    10794968
# 63  Australia  1967    11872264
# 64  Australia  1972    13177000
# 65  Australia  1977    14074100
# 66  Australia  1982    15184200
# 67  Australia  1987    16257249
# 68  Australia  1992    17481977
# 69  Australia  1997    18565243
# 70  Australia  2002    19546792
# 71  Australia  2007    20434176

# %%
country6 = data[data.country == 'Austria']

country6
# Out:
#     country  year  population
# 72  Austria  1952     6927772
# 73  Austria  1957     6965860
# 74  Austria  1962     7129864
# 75  Austria  1967     7376998
# 76  Austria  1972     7544201
# 77  Austria  1977     7568430
# 78  Austria  1982     7574613
# 79  Austria  1987     7578903
# 80  Austria  1992     7914969
# 81  Austria  1997     8069876
# 82  Austria  2002     8148312
# 83  Austria  2007     8199783

# %%
plt.plot(country5.year,country5.population/10**6)
plt.plot(country6.year,country6.population/10**6)
plt.title('comparision of two countries')
plt.xlabel('year')
plt.ylabel('population')
plt.legend(["this is country5","this is country6"])
plt.show()

# %%
country7 = data[data.country == 'Bangladesh']

country7
# Out:
#         country  year  population
# 96   Bangladesh  1952    46886859
# 97   Bangladesh  1957    51365468
# 98   Bangladesh  1962    56839289
# 99   Bangladesh  1967    62821884
# 100  Bangladesh  1972    70759295
# 101  Bangladesh  1977    80428306
# 102  Bangladesh  1982    93074406
# 103  Bangladesh  1987   103764241
# 104  Bangladesh  1992   113704579
# 105  Bangladesh  1997   123315288
# 106  Bangladesh  2002   135656790
# 107  Bangladesh  2007   150448339

# %%
country8 = data[data.country == 'Belgium']

country8
# Out:
#      country  year  population
# 108  Belgium  1952     8730405
# 109  Belgium  1957     8989111
# 110  Belgium  1962     9218400
# 111  Belgium  1967     9556500
# 112  Belgium  1972     9709100
# 113  Belgium  1977     9821800
# 114  Belgium  1982     9856303
# 115  Belgium  1987     9870200
# 116  Belgium  1992    10045622
# 117  Belgium  1997    10199787
# 118  Belgium  2002    10311970
# 119  Belgium  2007    10392226

# %%
plt.plot(country7.year,country7.population/10**6)
plt.plot(country8.year,country8.population/10**6)
plt.title('comparision of two countries')
plt.xlabel('year')
plt.ylabel('population')
plt.legend(["this is country7","this is country8"])
plt.show()
